# %% [markdown]
# https://towardsdatascience.com/an-end-to-end-data-science-project-that-will-boost-your-portfolio-c53cfe16f0e3
#
# # AirB&B heatmap plot for prediction of the price of a flat along with parameter correlation

# %% [markdown]
# ### Summary of this project:
# The purpose of this project is to apply known knowledge of importing files, exporting data into dataframes, manipulating the values within said dataframes, mapping an area with coordinate markers,

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
from math import radians, cos, sin, asin, sqrt
from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.externals import joblib


# %matplotlib inline
# Out:
# C:\Users\jeffc\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
#os.chdir('AmsterdamABNB')

print(os.getcwd())
# Out:
# C:\Users\jeffc\Documents\GitHub\jeff-mos-def.github.io-master\JupyterNotebook\AmsterdamABNB

# %%
df = pd.read_json('amsterdam.json')
#df = pd.read_json('input/dataset.json', orient='records')

df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15148 entries, 0 to 15180
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_listings_count             15148 non-null  float64
#  1   accommodates                    15148 non-null  int64
#  2   bathrooms                       15148 non-null  float64
#  3   bedrooms                        15148 non-null  float64
#  4   guests_included                 15148 non-null  int64
#  5   minimum_nights                  15148 non-null  int64
#  6   number_of_reviews               15148 non-null  int64
#  7   calculated_host_listings_count  15148 non-null  int64
#  8   price                           15148 non-null  object
#  9   latitude                        15148 non-null  float64
#  10  longitude                       15148 non-null  float64
#  11  room_type                       15148 non-null  object
#  12  instant_bookable                15148 non-null  object
# dtypes: float64(5), int64(5), object(3)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#    host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                  1.0             6        1.0       2.0                1
# 1                  1.0             2        1.0       1.0                1
# 2                  1.0             2        1.0       1.0                2
# 3                  2.0             4        1.0       2.0                2
# 4                  1.0             2        1.0       1.0                1
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count    price  \
# 0               3                  4                               1  $145.00
# 1               2                 17                               1   $88.00
# 2               2                  4                               1  $130.00
# 3               4                  2                               2  $110.00
# 4               3                 10                               1  $115.00
#
#     latitude  longitude        room_type instant_bookable
# 0  52.361173   4.866755  Entire home/apt                f
# 1  52.370237   4.859507  Entire home/apt                f
# 2  52.362016   4.866872  Entire home/apt                f
# 3  52.365826   4.858178  Entire home/apt                f
# 4  52.364179   4.864885  Entire home/apt                f

# %%
max(df['price'].values, key=len)
# Out:
# '$1,305.00'

# %%
df['price']=df['price'].apply(lambda x: x.replace('$',''))
df['price']=df['price'].apply(lambda x: x.replace(',',''))

df['price']=pd.to_numeric(df['price'])

# %%
#amsterdam = {'lat' : 52.3667, 'long' : 4.8945}

# %%
#from folium
m = folium.Map(location=[52.3667, 4.8945], zoom_start=13)

#m.save('index.html')

# %%
from folium import plugins

# %%
heatmap = df[['latitude','longitude','price']].round(4).groupby(['latitude','longitude']).sum().reset_index().values.tolist()

#plot heatmap
m.add_child(plugins.HeatMap(heatmap, radius=9, max_zoom=10))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
city_center = {'lat' : 52.379189, 'long' : 4.899431}
willemspark = {'lat' : 52.3534, 'long' : 4.8607}
schiphol = {'lat': 52.3105, 'long' : 4.7683}
leidseplein = {'lat' : 52.365051, 'long' : 4.884429}

# %%
#from math: sin,cos,acos,asin

def haversine(lon1, lat1, lon2, lat2):
    """"
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)
    """
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1)*cos(lat2)*sin(dlon/2)**2
    c=2*asin(sqrt(a))
    km = 6367*c
    return km

# %%
for index, row in df.iterrows():
    df.loc[index, 'distance_from_center'] = haversine(city_center['long'],
                                                      city_center['lat'], row['longitude'], row['latitude'])
    df.loc[index, 'distance_from_willemspark'] = haversine(willemspark['long'],
                                                           willemspark['lat'], row['longitude'], row['latitude'])
    df.loc[index, 'distance_from_schiphol'] = haversine(schiphol['long'],
                                                        schiphol['lat'], row['longitude'], row['latitude'])
    df.loc[index, 'distance_from_leidseplein'] = haversine(leidseplein['long'],
                                                           leidseplein['lat'], row['longitude'], row['latitude'])

# %%
#folium.Marker(52.379189, 4.899431, popup='<i>City Centre</i>', tooltip=tooltip).add_to(m)
#folium.Marker(willemspark.values(), popup='<i>Willemspark</i>').add_to(m)
#folium.Marker(schiphol.values(), popup='<i>Schiphol</i>').add_to(m)
#folium.Marker(leidseplein.values(), popup='<i>Leidseplein</i>').add_to(m)

folium.Marker(
    location=[52.379189, 4.899431],
    popup='City Center',
    icon=folium.Icon(icon='screenshot', color='green')
).add_to(m)

folium.Marker(
    location=[52.3534, 4.8607],
    popup='Willemspark',
    icon=folium.Icon(icon='screenshot', color='green')
).add_to(m)

folium.Marker(
    location=[52.3105, 4.7683],
    popup='Schiphol',
    icon=folium.Icon(icon='screenshot', color='green')
).add_to(m)

folium.Marker(
    location=[52.365051, 4.884429],
    popup='Leidseplein',
    icon=folium.Icon(icon='screenshot', color='green')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                  1.0             6        1.0       2.0                1
# 1                  1.0             2        1.0       1.0                1
# 2                  1.0             2        1.0       1.0                2
# 3                  2.0             4        1.0       2.0                2
# 4                  1.0             2        1.0       1.0                1
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  price  \
# 0               3                  4                               1  145.0
# 1               2                 17                               1   88.0
# 2               2                  4                               1  130.0
# 3               4                  2                               2  110.0
# 4               3                 10                               1  115.0
#
#     latitude  longitude  distance_from_center  distance_from_willemspark  \
# 0  52.361173   4.866755              2.987199                   0.956539
# 1  52.370237   4.859507              2.885443                   1.872716
# 2  52.362016   4.866872              2.919191                   1.045060
# 3  52.365826   4.858178              3.168346                   1.391400
# 4  52.364179   4.864885              2.876726                   1.231058
#
#    distance_from_schiphol  distance_from_leidseplein  \
# 0                8.740716                   1.274440
# 1                9.078094                   1.786520
# 2                8.807370                   1.238186
# 3                8.662530                   1.783358
# 4                8.865087                   1.329737
#
#    room_type_Entire home/apt  room_type_Private room  room_type_Shared room  \
# 0                          1                       0                      0
# 1                          1                       0                      0
# 2                          1                       0                      0
# 3                          1                       0                      0
# 4                          1                       0                      0
#
#    instant_bookable_f  instant_bookable_t
# 0                   1                   0
# 1                   1                   0
# 2                   1                   0
# 3                   1                   0
# 4                   1                   0

# %%
df.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col1 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col2 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col3 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col5 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col6 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col7 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col8 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col9 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col10 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col11 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col12 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col13 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col14 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col15 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col16 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col17 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col18 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow0_col19 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col0 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col2 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col3 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col4 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col5 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col6 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col7 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col8 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col9 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col10 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col11 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col12 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col13 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col14 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col15 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col16 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col17 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col18 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow1_col19 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col0 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col3 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col5 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col6 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col7 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col8 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col9 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col10 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col11 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col12 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col13 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col14 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col15 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col16 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col17 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col18 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_2f411e24_826a_11ea_9b52_d89c6782d74crow2_col19 {
#             background-color:  #6fa7ce;

# %%
X = df.drop(['price'], axis=1)

y = df['price']

# %%
#from sklearn, test/train/split
X_train, X_test, y_train, y_test = train_test_split(X ,y, test_size=0.2, random_state=1)

# %%
#pip install lightgbm

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)

# %%
from sklearn import metrics
r2 = metrics.r2_score(y_test, y_pred)
mae = metrics.mean_absolute_error(y_test, y_pred)
scores = pd.DataFrame({'Baseline (regression)' : [r2, mae]}, index=['R2', 'MAE'])
scores
# Out:
#      Baseline (regression)
# R2                0.395155
# MAE              37.627580

# %%
if 'svr_gridsearch_cv.pkl' in os.listdir():
    
    svr_grid_search = joblib.load('svr_gridsearch_cv.pkl')
    
else:
    
    from sklearn.svm import SVR
svr = SVR()
param_grid = [
      {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
      {'C': [1, 10, 100, 1000], 'gamma': [0.01, 0.001, 0.0001], 'kernel': ['rbf']}]
svr_grid_search = GridSearchCV(svr, param_grid=param_grid, 
                                   n_jobs=-1, 
                                   scoring=['r2', 'neg_mean_squared_error'],
                                  refit='neg_mean_squared_error', verbose=100)
svr_grid_search.fit(X_train, y_train)
joblib.dump(svr_grid_search.best_estimator_, 'svr_gridsearch_cv.pkl')
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   24.8s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   27.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   30.5s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  1.6min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  1.7min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  1.7min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  1.7min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  2.1min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  9.9min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed: 10.2min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed: 10.6min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed: 10.8min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed: 11.0min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed: 11.2min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 11.3min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 11.4min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 11.5min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 11.5min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 11.6min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).[Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 11.6min
#
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 11.7min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 11.9min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 11.9min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 12.0min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 12.1min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 12.1min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 12.2min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 12.3min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 12.3min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 12.4min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 12.5min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 12.5min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 12.5min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 12.6min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 12.6min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 12.7min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 12.8min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 12.8min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 12.8min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 13.0min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 13.0min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 13.1min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 13.2min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 13.3min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 13.4min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 13.5min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 13.5min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 13.6min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 13.6min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 13.7min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 13.8min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 13.8min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 13.9min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 13.9min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 14.0min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 14.0min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 14.1min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 14.1min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 14.7min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 14.8min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 14.9min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 15.1min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 15.2min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  66 out of  80 | elapsed: 15.2min remaining:  3.2min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  67 out of  80 | elapsed: 15.2min remaining:  3.0min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  68 out of  80 | elapsed: 15.5min remaining:  2.7min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  69 out of  80 | elapsed: 15.5min remaining:  2.5min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  70 out of  80 | elapsed: 15.5min remaining:  2.2min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  71 out of  80 | elapsed: 15.7min remaining:  2.0min
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  72 out of  80 | elapsed: 15.7min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done  73 out of  80 | elapsed: 15.7min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done  74 out of  80 | elapsed: 15.9min remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done  75 out of  80 | elapsed: 15.9min remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done  76 out of  80 | elapsed: 113.7min remaining:  6.0min
# [Parallel(n_jobs=-1)]: Done  77 out of  80 | elapsed: 122.6min remaining:  4.8min
# [Parallel(n_jobs=-1)]: Done  78 out of  80 | elapsed: 127.1min remaining:  3.3min
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed: 131.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed: 131.6min finished
# ['svr_gridsearch_cv.pkl']

# %%
#from lightgbm, LGBMRegressor

reg = LGBMRegressor()

reg.fit(X_train,y_train)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
from sklearn import metrics
metrics.mean_squared_error(y_test,reg.predict(X_test))
# Out:
# 3664.2359406906335

# %%
imp_feat=pd.Series(reg.feature_importances_,index=X.columns.tolist())
imp_feat.sort_values(ascending=False).plot(kind='bar', )

# %%
pred=reg.predict(X_test)
pred
# Out:
# array([ 74.09937064, 102.05940354, 151.9638817 , ..., 112.45245515,
#        102.10230051, 194.6893563 ])

# %%
Y=pd.DataFrame(df['price'])

# %%
Errors=y_test-pred

# %%
plt.scatter(y_test, Errors, alpha=0.5)

# %%
metrics.mean_absolute_error(y_pred=reg.predict(X_test), y_true=y_test)
# Out:
# 33.8213727097549

# %%
if 'gbm_gridsearch_cv.pkl' in os.listdir():
    
    gbm_grid_search = joblib.load('gbm_gridsearch_cv.pkl')
    
else:
    
    from lightgbm import LGBMRegressor
gbm = LGBMRegressor()
param_grid = {
    'learning_rate': [0.01, 0.1, 1],
    'n_estimators': [50, 100, 150],
    'boosting_type': ['gbdt', 'dart'],
    'num_leaves': [15, 31, 50]}
gbm_grid_search = GridSearchCV(gbm, param_grid=param_grid, 
                                   n_jobs=-1, 
                                   scoring=['r2', 'neg_mean_squared_error'],
                                  refit='neg_mean_squared_error', verbose=100)
gbm_grid_search.fit(X_train, y_train)
joblib.dump(gbm_grid_search.best_estimator_, 'gbm_gridsearch_cv.pkl')
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    5.6s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    5.7s
#
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    5.8s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    5.8s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    6.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    6.1s
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    6.4s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    6.5s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    6.8s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    7.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    7.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).[Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    7.1s
#
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    7.1s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    7.1s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    7.4s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    7.5s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    8.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    8.1s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    8.4s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    8.4s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    8.5s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    8.6s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    8.9s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    9.3s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    9.8s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   10.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   10.1s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   10.2s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   10.2s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   10.3s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.6s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   11.3s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   11.9s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   12.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   12.1s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   12.1s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   12.2s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   12.6s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   12.7s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   12.7s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   12.8s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   13.1s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   13.2s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   13.2s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   13.4s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   13.6s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   13.8s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   13.8s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   13.9s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).[Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   13.9s
#
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   14.3s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   14.5s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   14.6s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   14.7s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# ...
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:   53.2s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:   53.4s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:   53.5s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 245 tasks      | elapsed:   53.6s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 246 tasks      | elapsed:   54.5s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed:   54.6s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:   54.9s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed:   55.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:   55.2s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 251 tasks      | elapsed:   56.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:   56.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 253 tasks      | elapsed:   56.1s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:   56.9s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed:   57.1s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 258 out of 270 | elapsed:   57.5s remaining:    2.6s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9694,), dtype=int32).
# Pickling array (shape=(2424,), dtype=int32).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 261 out of 270 | elapsed:   59.9s remaining:    2.0s
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9, 12118), dtype=float64).
# Pickling array (shape=(5, 12118), dtype=int64).
# Pickling array (shape=(5, 12118), dtype=uint8).
# Pickling array (shape=(9,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(9,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(12118,), dtype=float64).
# Pickling array (shape=(12118,), dtype=int64).
# Pickling array (shape=(9695,), dtype=int32).
# Pickling array (shape=(2423,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 264 out of 270 | elapsed:  1.0min remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 267 out of 270 | elapsed:  1.0min remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:  1.1min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:  1.1min finished
# ['gbm_gridsearch_cv.pkl']

# %%
r2 = metrics.r2_score(y_test, y_pred)
mae = metrics.mean_absolute_error(y_test, y_pred)
scores = pd.DataFrame({'Baseline (regression)': [r2, mae],
                       'SVR' : [r2, mae]}, index=['R2', 'MAE'])
scores
# Out:
#      Baseline (regression)        SVR
# R2                0.395155   0.395155
# MAE              37.627580  37.627580
